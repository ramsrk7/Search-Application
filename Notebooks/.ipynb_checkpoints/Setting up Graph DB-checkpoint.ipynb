# %% [markdown]
# https://github.com/stellasia/nodes2022
#
# https://www.youtube.com/watch?v=DKziks5jQvc&ab_channel=Neo4j

# %%
from typing import Optional


class Movie:
    def __init__(self, title: str, released: Optional[int] = None):
        self.title = title
        self.released = released


def build_create_movie_query(movie: Movie):
    query = "CREATE (node:Movie) SET node.title=$title, node.released=$released"
    params = {
        "title": movie.title,
        "released": movie.released
    }
    return query, params

# %%
import pytest

def test_movie_object():
    m = Movie(title="The Matrix")
    assert m.title == "The Matrix"
    assert m.released is None



def movie():
    return Movie(title="NODES", released=2022)


def test_movie_create_query(movie):
    q, p = build_create_movie_query(movie)
    assert q == "CREATE (node:Movie) SET node.title=$title, node.released=$released"
    assert p == {"title": movie.title, "released": movie.released}

# %%
test_movie_object()

# %%
a = movie()

# %%
a.released
# Out:
# 2022

# %% [markdown]
# ## Pilot
#
#
# Node File:
# * Name
# * Date Created
# * Date Modified
# * Format
#
# Node Keyword:
#
# * Name
#
# Relationship:
#
# * PER
# * LOC
# * ORG
# * MIS
#
# Check if a node exists:
# * If yes, update.
# * Else Create.
#
# Syntax: Create:
#
# CREATE (a {name: 'Andy'})
# RETURN a.name
#
# CREATE (n:Person {name: 'Andy', title: 'Developer'})
#
# Syntax Delete:
# MATCH (m:Person {name: 'Mark'})
# DETACH DELETE m

# %%
class Helper:
    
    def formatProperties(self, properties):
        
        query = "{"
        
        for key,val in properties.items():      
            query += key
            query += ":'"
            query += val + "',"
        query = query[:-1] + "}"
        
        return query
            
Help = Helper()

# %%
class File:
    
    def __init__(self, name: str, date_created, date_modified, file_format, size):
        
        self.properties = {}
        self.properties['name'] = name
        self.properties['date_created'] = date_created
        self.properties['date_modified'] = date_modified
        self.properties['file_format'] = file_format
        self.properties['size'] = size
        self.type = "Files"
        
    def getProperties(self):
        
        return Help.formatProperties(self.properties)
        
        
class Keyword:
    
    def __init__(self, name, prop):
        
        self.properties = {}
        self.properties['name'] = name
        self.properties['property'] = prop
        self.type = 'Keywords'
        
    def getProperties(self):
        return Help.formatProperties(self.properties)
    
    def getRelationship(self):
        return self.relationship

# %%
class QueryGenerator:
    
    def __init__(self, conn = ""):
        self.conn = conn

    def delete(self, node: str, properties: str):
        
        query = "MATCH (m:" + node + " " + properties + ") DETACH DELETE m"
        return query

    def create(self, node: str, properties: str):
        
        query = "CREATE (n:" + node + " " + properties + ")"
        return query
    
    def update(self, node: str, properties: str):
        
        return self.delete(node, properties) + " " + self.create(node, properties)

    def check(self, node: str, properties: str):
        return 
    
    def connect_nodes(self, node1, node2, relationship):
        
        query = "MATCH (n1:" + node1.type + node1.getProperties() + "),"
        query += "(n2:" + node2.type + node2.getProperties() + ") "
        query += "CREATE (n1) - [:" + relationship + "] -> (n2)"
    
        return query
    
    def relationship_exists(self, node1, node2, relationship):
        
        query = "RETURN EXISTS( (:"+ node1.type + "{ name: '"+ node1.properties['name'] + "'})-[:"+ relationship + "]-"
        query += "(: " + node2.type + "{name: '" + node2.properties['name'] +"'}) )"
        
        return query

# %%
from py2neo import Graph


class Neo4jConnection:
    
    '''
    Get BOLT URL, username, pwd
    Create Session.
    Run queries through session.
    '''
    
    def __init__(self):
        self.uri = "bolt://localhost:7687"
        self.user = "neo4j"
        self.password = "neo4jneo4j"
        self.graph = None
        self.queryGenerator = QueryGenerator()
        
    def connect(self):
        
        self.graph = Graph(self.uri, auth=(self.user, self.password))
        return self.graph
        
    
    def run(self, node1, func=None, node2=None, relationship=None):
        
        
        query = ""
        
        if func == "CREATE":
            
            if self.exists(node1):
                print("Node Exists. Cannot create nodes with redundant names.")
                return -1
            
            query = self.queryGenerator.create(node1.type, node1.getProperties())
            
      
        elif func == "DELETE":
            
            if self.exists(node1) == False:
                print("Node doesn't exist")
                return -1
            
            query = self.queryGenerator.delete(node1.type, node1.getProperties())
            
        elif func == "UPDATE":
            pass
            
        elif func == "LINK":
            
            if node2 == None:
                print("Node2 Argument Missing")
                return -1
            if self.exists(node1) == False:
                print("Create Node 1")
                return -1
            if self.exists(node2) == False:
                print("Create Node 2")
                return -1
            if relationship == None:
                print("Add relationship")
                return -1
             
            if graphConn.graph.run(self.queryGenerator.relationship_exists(node1, node2, relationship)).evaluate():
                print("Relationship exists")
                return -1
                
            query = self.queryGenerator.connect_nodes(node1, node2, relationship)
            
        else:
            
            print("Unknown Function. Choose one of the following: [CREATE, DELETE, UPDATE, LINK]")
            return -1
            
        
        try:
            return self.graph.run(query)
        except:
            print("Query ERROR!")
            return -1
    
    def exists(self, node):
        
        count = self.graph.nodes.match(node.type, name=node.properties['name']).first()
        
        return False if count == None else True

# %%
file_node = File("/Users/ram/Desktop/Final-Project/Sample_Files/sample.pdf", "2022-09-30 13:58:48","2023-04-06 12:03:14","pdf", "200")
entity_node = Keyword("Chennai","Location")
entity_node2 = Keyword("San Jose","Location")

# %%
file_node.getProperties()
# Out:
# "{name:'/Users/ram/Desktop/Final-Project/Sample_Files/sample.pdf',date_created:'2022-09-30 13:58:48',date_modified:'2023-04-06 12:03:14',file_format:'pdf',size:'200'}"

# %%
entity_node.getProperties()
# Out:
# "{name:'Chennai',property:'Location'}"

# %%
graphConn = Neo4jConnection()

# %%
graphConn.connect()
# Out:
# Graph('bolt://localhost:7687')

# %%
entity_node.getProperties()
# Out:
# "{name:'Chennai',property:'Location'}"

# %%
graphConn.run(file_node, "CREATE")
# Out:
# (No data)

# %%
graphConn.run(entity_node, "CREATE")
# Out:
# Node Exists. Cannot create nodes with redundant names.
# -1

# %%
graphConn.run(entity_node2, "CREATE")
# Out:
# Node Exists. Cannot create nodes with redundant names.
# -1

# %%
graphConn.run(file_node, "LINK",entity_node, "HAS")
# Out:
# (No data)

# %%
graphConn.run(file_node, "LINK",entity_node2, "HAS")
# Out:
# (No data)

# %%
graphConn.run(entity_node, "LINK",entity_node2, "CITY")
# Out:
# (No data)

# %%
import subprocess

neo4j_home = "/Users/ram/Desktop/Final-Project/NEO4J-HOME"
server_config = "/Users/ram/Desktop/Final-Project/NEO4J-HOME/conf/neo4j.conf"


try:
    # Check if the Neo4j server is already running
    status_output = subprocess.check_output([f"{neo4j_home}/bin/neo4j", "status"], stderr=subprocess.STDOUT)

    if b"Neo4j is running" in status_output:
        print("Neo4j server is already running.")
    else:
        print("Starting Neo4j server...")
        subprocess.run([f"{neo4j_home}/bin/neo4j", "start", "-c", server_config])

except subprocess.CalledProcessError as e:
    # Handle the case where the command returned a non-zero exit status
    if e.returncode == 3:
        print("Neo4j server is not running. Starting Neo4j server...")
        subprocess.run([f"{neo4j_home}/bin/neo4j", "start", "-c", server_config])
    else:
        print(f"Error checking Neo4j server status: {e}")
# Out:
# Neo4j server is not running. Starting Neo4j server...

# %%
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-7-f22476c2033f> in <module>
# ----> 1 status_output = subprocess.check_output([f"{neo4j_home}/bin/neo4j", "status"], stderr=subprocess.STDOUT)
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409         kwargs['input'] = '' if kwargs.get('universal_newlines', False) else b''
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#     413
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         retcode = process.poll()
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

class EntityModel:
    
    def __init__(self):
        
        self.tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
        self.model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
        self.nlp = pipeline("ner", model=self.model, tokenizer=self.tokenizer)
        
    def getEntities(self,text):
        
        try:
            out = self.nlp(text)
            return out
        except Exception as e:
            print(e)

# %%
# !pip install pdf2image

# %%
import PyPDF2
import glob
import tempfile
from tqdm import tqdm
from datetime import datetime
import warnings
import os
warnings.filterwarnings("ignore", category=FutureWarning)
import textract
from docx2pdf import convert
from pdf2image import convert_from_bytes, convert_from_path
import matplotlib.pyplot as plt
from transformers import AutoFeatureExtractor, AutoModelForImageClassification
#import torch




class PreprocessFiles:
    
    def __init__(self):
        self.processor = AutoFeatureExtractor.from_pretrained("microsoft/dit-base-finetuned-rvlcdip")
        self.model = AutoModelForImageClassification.from_pretrained("microsoft/dit-base-finetuned-rvlcdip")
        
        
    
    
    def getType(self, path, show=False):
        
        docType = None
        images = None

        
        if path.endswith(".docx"):
            
#             pass
            
#             # Convert the DOCX file to PDF in memory
#             with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as tmp:
#                 convert(path, tmp.name)
#                 pdf_data = tmp.read()
                
#             images = convert_from_bytes(pdf_data)

            pass

        elif path.endswith(".pdf"):
            images = convert_from_path(path)
            
        if images:
            
            if show:
                plt.imshow(images[0])
                plt.show()
            inputs = self.processor(images=images[0], return_tensors="pt")
            outputs = self.model(**inputs)
            logits = outputs.logits

            # model predicts one of the 16 RVL-CDIP classes
            predicted_class_idx = logits.argmax(-1).item()
            docType = self.model.config.id2label[predicted_class_idx]
            
        return docType
            
            
    
        
    def pdf2txt(self, path, out):

        pdffileobj=open(path,'rb')
        pdfreader=PyPDF2.PdfFileReader(pdffileobj)
        x=pdfreader.numPages

        text = ""
        for i in range(x):
            pageobj=pdfreader.getPage(i)
            text+=pageobj.extractText()

        out_file=open(out,"a")
        out_file.writelines(text)
        
    def getMetaData(self, path):
        
        try:
            filename, file_extension = os.path.splitext(path)
            mtime = datetime.fromtimestamp(os.path.getmtime(path)).strftime('%Y-%m-%d %H:%M:%S')
            ctime = datetime.fromtimestamp(os.path.getctime(path)).strftime('%Y-%m-%d %H:%M:%S')
            size = os.path.getsize(path)
            name = path    
            d = {'name':name, 'format':file_extension, 'mtime': str(mtime), 'ctime':str(ctime), 'size':size/1000}
            return d
        
        except Exception as e:
            return e
            
    
    def convertPDF(self, path=None):
        
        try:

            with open(path, 'rb') as pdf_file:
        # Create a PDF reader object
            
                # Create an empty string variable to store the text
                text = ""

                # Loop through each page in the PDF document
                #for i in range(num_pages):
                    # Get the current page object
                    #page = reader.getPage(i)

                    # Extract the text from the page
                    #page_text = page.extractText()

                    # Append the text to the overall string
                    #text += page_text
                text = textract.process(path)
                
                return text
            
        except Exception as e:
                
                return ""

# %%
from py2neo import Graph
import subprocess


class Neo4jConnection:
    
    '''
    Get BOLT URL, username, pwd
    Create Session.
    Run queries through session.
    '''
    
    def __init__(self, uri=None, user=None, password=None):
        self.uri = uri if uri else "bolt://localhost:7687"
        self.user = user if user else "neo4j"
        self.password = password if password else "neo4jneo4j"
        self.graph = None
        self.queryGenerator = QueryGenerator()
        
    def connect(self):
        
        try:
            self.graph = Graph(self.uri, auth=(self.user, self.password))
            return "OK"
        except Exception as e:
            return e
    
    def run(self, node1=None, func=None, node2=None, relationship=None):
        
        
        query = ""
        
        if func == "CREATE":
            
            
            if self.exists(node1):
                print("Node Exists. Cannot create nodes with redundant names.")
                return -1
            
            query = self.queryGenerator.create(node1.type, node1.getProperties())
            
        elif func == "IF_PATH_EXISTS":
            
            query = self.queryGenerator.check_file(node1, 'name')
            
        elif func=="MODIFIED_TIME":
            
            query = self.queryGenerator.check(name=node1, Type='Files', Property='mtime')
            
            
      
        elif func == "DELETE":
            
            if self.exists(node1) == False:
                print("Node doesn't exist")
                return -1
            
            query = self.queryGenerator.delete(node1.type, node1.getProperties())
            
        elif func == "UPDATE":
            pass
            
        elif func == "LINK":
            
            if node2 == None:
                print("Node2 Argument Missing")
                return -1
            if self.exists(node1) == False:
                print(self.exists(node1))
                print("Create Node 1")
                return -1
            if self.exists(node2) == False:
                print("Create Node 2")
                return -1
            if relationship == None:
                print("Add relationship")
                return -1
             
            if self.graph.run(self.queryGenerator.relationship_exists(node1, node2, relationship)).evaluate():
                print("Relationship exists")
                return -1
                
            query = self.queryGenerator.connect_nodes(node1, node2, relationship)
            
        else:
            
            print("Unknown Function. Choose one of the following: [CREATE, DELETE, UPDATE, LINK]")
            return -1
            
        
        try:
            return self.graph.run(query)
        except:
            print("Query ERROR!")
            return -1
    
    def exists(self, node):
        
        prop = 'name'
        
        count = self.graph.nodes.match(node.type, name=node.properties[prop]).first()
        print(count)
        
        return False if count == None else True
        
    def startServer(self):

        neo4j_home = "/Users/ram/Desktop/Final-Project/NEO4J-HOME"
        server_config = "/path/to/n,eo4j/conf/neo4j.conf"

        # Check if the Neo4j server is already running
        status_output = subprocess.check_output([f"{neo4j_home}/bin/neo4j", "status"], stderr=subprocess.STDOUT)

        if b"Neo4j is running" in status_output:
            print("Neo4j server is already running.")
        else:
            print("Starting Neo4j server...")
            subprocess.run([f"{neo4j_home}/bin/neo4j", "start", "-c", server_config])

        

class File:
    
    def __init__(self, properties: dict , type="Files"):
        
        self.properties = {}
        
        for key, val in properties.items():
            self.properties[key] = val
#             self.properties['date_created'] = date_created
#             self.properties['date_modified'] = date_modified
#             self.properties['file_format'] = file_format
        self.type = type
        self.Help = Helper()
        
    def getProperties(self):
        
        return self.Help.formatProperties(self.properties)
        
        
class Keyword:
    
    def __init__(self, name, relationship, type="Keywords"):
        
        self.properties = {}
        self.properties['name'] = name
        self.relationship = relationship
        self.type = type
        self.Help = Helper()
        
    def getProperties(self):
        return self.Help.formatProperties(self.properties)
    
    def getRelationship(self):
        return self.relationship
    
        

class QueryGenerator:
    
    def __init__(self, conn=None):
        self.conn = conn

    def delete(self, node: str, properties: str):
        
        query = "MATCH (m:" + node + " " + properties + ") DETACH DELETE m"
        return query

    def create(self, node: str, properties: str):
        
        query = "CREATE (n:" + node + " " + properties + ")"
        return query
    
    def update(self, node: str, properties: str):
        
        return self.delete(node, properties) + " " + self.create(node, properties)

    def check(self, name: str, Type: str, Property: str):
        query = "MATCH (n1:" + Type + "{name:'" + name + "'})" + "RETURN n1." + Property
        return query 
    
    def check_file(self, name: str, Property: str):
        query = "MATCH (n1) WHERE n1." + Property + "= '" + name + "' RETURN n1"
        return query 
    
    def connect_nodes(self, node1, node2, relationship):
        
        query = "MATCH (n1:" + node1.type + node1.getProperties() + "),"
        query += "(n2:" + node2.type + node2.getProperties() + ") "
        query += "CREATE (n1) - [:" + relationship + "] -> (n2)"
    
        return query
    
    def relationship_exists(self, node1, node2, relationship):
        
        query = "RETURN EXISTS( (:"+ node1.type + "{ name: '"+ node1.properties['name'] + "'})-[:"+ relationship + "]-"
        query += "(:" + node2.type + "{name: '" + node2.properties['name'] +"'}) )"
        
        
        query = "MATCH (a:" + node1.type + "{name: '"+ node1.properties['name'] +  "'}), (b:" + node2.type + "{name: '" + node2.properties['name'] + "'}) "
        query += " RETURN EXISTS ((a)-[:" + relationship + "]-(b))"
        
        return query
        

class Helper:
    
    def formatProperties(self, properties):
        
        query = "{"
        
        for key,val in properties.items():      
            query += key
            if type(val) == str:
                query += ":'"
                query += val + "',"
            else:
                query += ":"
                query += str(val) + ","
                
        query = query[:-1] + "}"
        
        return query

# %%
DB = Neo4jConnection()

# %%
DB.connect()
# Out:
# 'OK'

# %%
preProcess = PreprocessFiles()
NLP = EntityModel()

# %%
path = "/Users/ram/Desktop/Final-Project/Sample_Files"

# %%
# Get a list of all files in the directory
file_list = os.listdir(path)

# Filter the list to include only PDF files
pdf_list = [path+"/"+f for f in file_list if f.endswith(".pdf")]
all_list = [path+"/"+f for f in file_list]

# %%
all_list
# Out:
# ['/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/text summarisation.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/D14-1067.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/HW1_Ramkumar_Sivakumar.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/.DS_Store',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/tfs.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar_Sivakumar_SJSU.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/Setting up Graph DB.ipynb',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/1804.0703 3.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/Lease Contract.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/ACTIVITY LOG.docx',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/BERT.pdf',
#  '/Users/ram/Desktop/Final-Project/Sample_Files/WorkBook_2.1.pdf',
# ...

# %%
def formatEntities(NER):
    entities = []
    element = len(entities)
    #print(NER)
            
    for i in range(0, len(NER)):
        
        try:

            if NER[i]['entity'][0] == 'B' and NER[i]['word'][0] != '#':
                entities.append({'entity':NER[i]['entity'][2:], 'word':NER[i]['word'], 'start':NER[i]['start'], 'end':NER[i]['end']})
                element = len(entities) - 1

            else:



                if NER[i]['word'][0] == '#':

                    entities[-1]['word'] += NER[i]['word'].replace('#','')

                else:
                    entities[-1]['word'] += ' ' +  NER[i]['word'].replace('#','')
                entities[-1]['end'] = NER[i]['end']
        except Exception as e:
            print(e, NER[i])
            
    return entities

# %%
data = []

for f in all_list:
    
    print(f)
    l = preProcess.getMetaData(f)

    func = None
    
    cursor1 = DB.run(node1=f, func='IF_PATH_EXISTS')
    if len(list(cursor1)) >= 1:
        cursor2 = DB.run(node1=f, func='MODIFIED_TIME')
        time = [record for record in cursor2][0]
        print(time)
        print(str(time).replace("'",""),str(l['mtime']) )
        if str(time).replace("'","") != str(l['mtime']):
            func = 'UPDATE'
               
    else:
        func = 'CREATE'
        
    print(func)
        
    if func:
        l = preProcess.getMetaData(f)
        text = preProcess.convertPDF(f)
        if isinstance(text, bytes):
            text = text.decode('utf-8')
            l['numPages'] = text.count('\x0c') + 1
        else:
            l['numPages'] = len(text.split('\f'))
        #print(text)

        NER = NLP.getEntities(text)
        entities = formatEntities(NER)

        print(len(entities))
        
        node = File(l)
        cursor = DB.run(node1=node, func=func)
        print("Creating...")
        print(cursor)
        
        for ent in entities:
            entity = Keyword(name=ent['word'], relationship=ent['entity'])
            print(entity.getProperties(), entity.getRelationship())
            cursor = DB.run(node1=entity, func='CREATE')
            #cursor = DB.run(node1=File(l), func='CREATE')
            cursor = DB.run(node1=node, node2=entity, func='LINK', relationship=entity.getRelationship())
        
        docType = preProcess.getType(f,True)
        if docType:
            entity = Keyword(name=docType, relationship='TYPE')
            cursor = DB.run(node1=entity, func='CREATE')
            cursor = DB.run(node1=node, node2=entity, func='LINK', relationship=entity.getRelationship())
        
      

#     print(entities)
    
    
    
    
    
    
    
#print(data)
# Out:
# /Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf
# '2022-09-30 13:58:48'
# 2022-09-30 13:58:48 2022-09-30 13:58:48
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/text summarisation.pdf
# '2022-09-26 16:13:44'
# 2022-09-26 16:13:44 2022-09-26 16:13:44
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/D14-1067.pdf
# '2022-09-26 22:18:13'
# 2022-09-26 22:18:13 2022-09-26 22:18:13
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/HW1_Ramkumar_Sivakumar.pdf
# '2022-10-24 19:46:14'
# 2022-10-24 19:46:14 2022-10-24 19:46:14
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/.DS_Store
# '2023-05-04 16:07:51'
# 2023-05-04 16:07:51 2023-05-04 16:07:51
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/tfs.pdf
# '2022-09-26 00:23:11'
# 2022-09-26 00:23:11 2022-09-26 00:23:11
# None
# /Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar_Sivakumar_SJSU.pdf
# '2022-09-22 21:11:20'
# 2022-09-22 21:11:20 2022-09-22 21:11:20
# None
# ...

# %%
queryGenerator = QueryGenerator()

# %%
queryGenerator.check(name=pdf_list[0], Type='Files', Property='mtime')
# Out:
# "MATCH (n1:Files{name:'/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf'})RETURN n1.mtime"

# %%
pdf_list[0]
# Out:
# '/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf'

# %%
preProcess.getType(all_list[8],True)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588         if "Pages" not in d:
# --> 589             raise ValueError
#     590
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-345-f7ed22b87226> in <module>
# ----> 1 preProcess.getType(all_list[8],True)
#
# <ipython-input-342-1b3fff9ab9c1> in getType(self, path, show)
#      38                 pdf_data = tmp.read()
#      39
# ---> 40             images = convert_from_bytes(pdf_data)
#      41         elif path.endswith(".pdf"):
#      42             images = convert_from_path(path)
#
# ...

# %%
pdf_list[0]
# Out:
# '/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf'

# %%
query = QueryGenerator()

# %%
query.check_file('Ram', 'name')
# Out:
# "MATCH (n1) WHERE n1.name= 'Ram' RETURN n1"

# %%
ret = DB.run(query.check_file(pdf_list[0], 'path'))

# %%
len(list(ret))
# Out:
# 1

# %%
ret = DB.run(query.check(pdf_list[0], 'File','mtime'))
# Out:
# Unknown Function. Choose one of the following: [CREATE, DELETE, UPDATE, LINK]

# %%
len(list(ret))
# Out:
# 0

# %%
query.check(pdf_list[0], 'File','mtime')
# Out:
# "MATCH (n1:File{path:'/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf'})RETURN n1.mtime"

# %%
# Out:
# /Users/ram/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
nlp 
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# Downloading:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/829 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]
# [{'entity': 'B-PER', 'score': 0.9990139, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
NLP = EntityModel()

# %%
NLP1.getEntities()

# %%
help(NLP1)
# Out:
# Help on EntityModel in module __main__ object:
#
# class EntityModel(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  getEntities(text)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from transformers import AutoFeatureExtractor, AutoModelForImageClassification
import torch

processor = AutoFeatureExtractor.from_pretrained("microsoft/dit-base-finetuned-rvlcdip")
model = AutoModelForImageClassification.from_pretrained("microsoft/dit-base-finetuned-rvlcdip")

# %%
inputs = processor(images=img, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits

# model predicts one of the 16 RVL-CDIP classes
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: scientific publication

# %%
# !pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 19.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=aebc8fe3dea037ef9846c789393ba1adbd4e6a6790468841de2a26d9c99a271e
#   Stored in directory: /Users/ram/Library/Caches/pip/wheels/32/b8/b2/c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# ...

# %%
import docx
from PIL import Image
import matplotlib.pyplot as plt

doc = docx.Document(all_list[8])

# Extract the text and images from the file
text = []
images = []
for para in doc.paragraphs:
    
    text.append(para.text)
for element in doc.element.body:
    if element.tag.endswith('graphic') and element[0].tag.endswith('blip'):
        images.append(element[0].attrib['{http://schemas.openxmlformats.org/officeDocument/2006/relationships}embed'])

# Create an image from the extracted data
img = Image.new('RGB', (800, 600), color='white')
draw = ImageDraw.Draw(img)
for i, t in enumerate(text):
    draw.text((10, 10 + i * 20), t, fill='black')
for i, im in enumerate(images):
    with open(f'word/media/{im}.png', 'rb') as f:
        img_data = io.BytesIO(f.read())
    img = Image.open(img_data)
    plt.imshow(img)
    plt.show()

# %%
for element in doc.paragraphs:
    print(element)

# %%
path = "/Users/ram/Desktop/Final-Project/Sample_Files"

# %%
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

class MyHandler(FileSystemEventHandler):
    def on_modified(self, event):
        if not event.is_directory:
            print("File %s was just modified" % event.src_path)

if __name__ == "__main__":
    event_handler = MyHandler()
    observer = Observer()
    observer.schedule(event_handler, path=path, recursive=False)
    observer.start()
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

# %%
import threading
from time import sleep

def task1():
    while True:
        print("Task 1 running...")
        sleep(20)
    
def task2():
    while True:
        print("Task 2 running...") # Wait for 10 seconds

if __name__ == "__main__":
    t1 = threading.Thread(target=task1)
    t2 = threading.Thread(target=task2)

    t2.start()
    t1.start()
    
    t2.join()
    t1.join()
# Out:
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# Task 1 running...
# ...
