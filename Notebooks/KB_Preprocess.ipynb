# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-2.11.1-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.4/220.4 kB 736.1 kB/s eta 0:00:0000:0100:01
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Installing collected packages: typing-extensions, PyPDF2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires grpcio~=1.32.0, but you have grpcio 1.42.0 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.23.3 which is incompatible.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# tensorflow-text 2.6.0 requires tensorflow<2.7,>=2.6.0, but you have tensorflow 2.4.1 which is incompatible.
# rasa 3.0.0 requires google-auth<3.0.0,>=2.3.3, but you have google-auth 1.35.0 which is incompatible.
# rasa 3.0.0 requires numpy<1.20.0,>=1.19.2, but you have numpy 1.23.3 which is incompatible.
# rasa 3.0.0 requires ruamel.yaml<0.17.0,>=0.16.5, but you have ruamel-yaml 0.15.87 which is incompatible.
# rasa 3.0.0 requires tensorflow<2.6.2,>=2.6, but you have tensorflow 2.4.1 which is incompatible.
# rasa 3.0.0 requires tensorflow-estimator<2.7,>=2.6, but you have tensorflow-estimator 2.4.0 which is incompatible.
# rasa 3.0.0 requires typing-extensions<4.0.0,>=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# rasa-sdk 3.0.0 requires typing-extensions<4.0.0,>=3.7.4, but you have typing-extensions 4.4.0 which is incompatible.
# rasa-core 0.8.6 requires fbmessenger<5.0.0, but you have fbmessenger 6.0.0 which is incompatible.
# rasa-core 0.8.6 requires pykwalify<=1.6.0, but you have pykwalify 1.8.0 which is incompatible.
# Successfully installed PyPDF2-2.11.1 typing-extensions-4.4.0

# %%
import PyPDF2
import glob
from tqdm import tqdm
from datetime import datetime
import warnings
import os
warnings.filterwarnings("ignore", category=FutureWarning)


class PreprocessFiles:
    
    def __init__(self,path,out=""):
        if path == "":
            print("No input path.")
            return 
        else:
            self.files = glob.glob(path)
            self.out = out
            #self.convert()
        
    
    def conv_func(self, path, out):

        
        pdffileobj=open(path,'rb')
        pdfreader=PyPDF2.PdfFileReader(pdffileobj)
        x=pdfreader.numPages

        text = ""
        for i in range(x):
            pageobj=pdfreader.getPage(i)
            text+=pageobj.extractText()

        out_file=open(out,"a")
        out_file.writelines(text)
        
    def getMetaData(self):
        
        l = []
        for f in self.files:
            mtime = datetime.fromtimestamp(os.path.getmtime(f)).strftime('%Y-%m-%d %H:%M:%S')
            ctime = datetime.fromtimestamp(os.path.getctime(f)).strftime('%Y-%m-%d %H:%M:%S')
            size = os.path.getsize(f)
            name = f
            
            
            d = {'path':name, 'mtime': mtime, 'ctime':ctime, 'size':size/1000}
            l.append(d)
        return l
            
    
    def convertToPDF(self):

        for f in tqdm(self.files):
            self.conv_func(f,self.out+f.replace(".pdf",".txt"))

# %%
preprocessing = PreprocessFiles("/Users/ram/Desktop/Final-Project/Sample_Files/*.pdf","Text/")

# %%
preprocessing.convertToPDF()
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-cc5aada0e131> in <module>
# ----> 1 preprocessing.convertToPDF()
#
# <ipython-input-22-7977b692dc0d> in convertToPDF(self)
#      53
#      54         for f in tqdm(self.files):
# ---> 55             self.conv_func(f,self.out+f.replace(".pdf",".txt"))
#      56
#      57
#
# <ipython-input-22-7977b692dc0d> in conv_func(self, path, out)
#      32             text+=pageobj.extractText()
#      33
# ---> 34         out_file=open(out,"a")
#      35         out_file.writelines(text)
#      36
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Text//Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.txt'

# %%
metadata = preprocessing.getMetaData()
metadata
# Out:
# [{'path': '/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar Sivakumar  EE - Timesheet.pdf',
#   'mtime': '2022-09-30 13:58:48',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 156.395},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/text summarisation.pdf',
#   'mtime': '2022-09-26 16:13:44',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 1855.56},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/D14-1067.pdf',
#   'mtime': '2022-09-26 22:18:13',
#   'ctime': '2023-04-06 12:03:13',
#   'size': 391.122},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/HW1_Ramkumar_Sivakumar.pdf',
#   'mtime': '2022-10-24 19:46:14',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 2575.579},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/tfs.pdf',
#   'mtime': '2022-09-26 00:23:11',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 254.448},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/Ramkumar_Sivakumar_SJSU.pdf',
#   'mtime': '2022-09-22 21:11:20',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 70.022},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/Lease Contract.pdf',
#   'mtime': '2022-10-12 21:51:23',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 704.709},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/BERT.pdf',
#   'mtime': '2022-09-28 18:46:11',
#   'ctime': '2023-04-06 12:03:13',
#   'size': 605.805},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/WorkBook_2.1.pdf',
#   'mtime': '2022-11-03 07:38:15',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 609.025},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/Direct_Answers_in_Google_Search_Results.pdf',
#   'mtime': '2022-09-26 17:05:34',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 3398.359},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/An_Integrated_Indexing_and_Search_Service_for_Distributed_File_Systems.pdf',
#   'mtime': '2022-09-27 22:05:52',
#   'ctime': '2023-04-06 12:03:13',
#   'size': 2809.359},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/Form.pdf',
#   'mtime': '2022-09-16 16:54:46',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 293.033},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/1804.07036.pdf',
#   'mtime': '2022-09-26 20:51:32',
#   'ctime': '2023-04-06 12:03:13',
#   'size': 375.655},
#  {'path': '/Users/ram/Desktop/Final-Project/Sample_Files/NLP_based_intelligent_news_search_engine_using_information_extraction_from_e-newspapers.pdf',
#   'mtime': '2022-09-26 16:35:16',
#   'ctime': '2023-04-06 12:03:14',
#   'size': 793.091}]

# %%
import pandas as pd

df = pd.DataFrame(metadata)
df['txt_size'] = [3,351,76,53,136,5,144,72, 183, 311, 4, 129, 78, 1]
df
# Out:
#                                                  path                mtime  \
# 0   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-30 13:58:48
# 1   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 16:13:44
# 2   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 22:18:13
# 3   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-10-24 19:46:14
# 4   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 00:23:11
# 5   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-22 21:11:20
# 6   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-10-12 21:51:23
# 7   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-28 18:46:11
# 8   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-11-03 07:38:15
# 9   /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 17:05:34
# 10  /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-27 22:05:52
# 11  /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-16 16:54:46
# 12  /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 20:51:32
# 13  /Users/ram/Desktop/Final-Project/Sample_Files/...  2022-09-26 16:35:16
#
#                   ctime      size  txt_size
# 0   2023-04-06 12:03:14   156.395         3
# 1   2023-04-06 12:03:14  1855.560       351
# 2   2023-04-06 12:03:13   391.122        76
# 3   2023-04-06 12:03:14  2575.579        53
# 4   2023-04-06 12:03:14   254.448       136
# 5   2023-04-06 12:03:14    70.022         5
# 6   2023-04-06 12:03:14   704.709       144
# 7   2023-04-06 12:03:13   605.805        72
# 8   2023-04-06 12:03:14   609.025       183
# 9   2023-04-06 12:03:14  3398.359       311
# 10  2023-04-06 12:03:13  2809.359         4
# 11  2023-04-06 12:03:14   293.033       129
# 12  2023-04-06 12:03:13   375.655        78
# 13  2023-04-06 12:03:14   793.091         1

# %%
df.to_csv("Metadata.csv")
